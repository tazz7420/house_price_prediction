# %%
from house_price_MLP import HousePriceModel
import warnings
warnings.filterwarnings("ignore")
warnings.warn("ignore")


NTPC_model = HousePriceModel('NTPC')
TPE_model = HousePriceModel('TPE')
KEL_model = HousePriceModel('KEL')

# %%
NTPC_model.trainModel()
TPE_model.trainModel()
KEL_model.trainModel()
# Out:
# model score: 0.9196940714379234
# model score: 0.8944089881281154
# model score: 0.891798155263546

# %%
NTPC_model.testModel('test_data')
TPE_model.testModel('test_data')
KEL_model.testModel('test_data')
# Out:
# ==========NTPC==========
# 預測房價落在實際房價+-10%內的機率為:61.8%
# 預測房價落在實際房價+-20%內的機率為:89.71000000000001%
# 預測房價落在實際房價+-30%內的機率為:96.47%
# Model Percentage Error: 9.31%
# mean_absolute_error: 0.31102661830236944
# mean_squared_error: 0.17672013644909929
# explained_variance_score: 0.8650976859700801
# r2_score: 0.8642936093968694
# ==========TPE==========
# 預測房價落在實際房價+-10%內的機率為:59.84%
# 預測房價落在實際房價+-20%內的機率為:88.44%
# 預測房價落在實際房價+-30%內的機率為:96.39999999999999%
# Model Percentage Error: 9.79%
# mean_absolute_error: 0.33165922992601676
# mean_squared_error: 0.20435053276347281
# explained_variance_score: 0.8597920055759672
# r2_score: 0.8597682577130608
# ==========KEL==========
# 預測房價落在實際房價+-10%內的機率為:44.73%
# 預測房價落在實際房價+-20%內的機率為:77.13%
# 預測房價落在實際房價+-30%內的機率為:91.25999999999999%
# Model Percentage Error: 13.08%
# mean_absolute_error: 0.44809068816623077
# mean_squared_error: 0.3428163744189034
# explained_variance_score: 0.8114141786238204
# r2_score: 0.7904685017613428
