# %% [markdown]
# # 處理房屋周遭環境資料(政府開放資料)

# %%
import pandas as pd
import geopandas as gpd
import csv
import re
from shapely.geometry import Point

import sys, os
sys.path.append("..")
import python.full_to_half as htf
import python.write_coordinate_to_csv as wctc
print('Pandas version: ', pd.__version__)
print('Geopandas version: ', gpd.__version__)
# Out:
# Pandas version:  1.4.3
# Geopandas version:  0.11.0

# %%
# 開放資料地址轉坐標
df = pd.read_csv(r'../rawdata/medical_facilities/pharmacy.csv', encoding = 'utf-8')
df.head()
# Out:
#   機構狀態      機構名稱 地址縣市別 地址鄉鎮市區      地址街道巷弄號 負責人姓名 負責人性別           電話 是否為健保特約藥局
# 0   開業  活力健康藥妝藥局   臺北市    中正區  中華路二段315巷1號   蕭聖鈞     男     23392625         Y
# 1   開業    建祥武昌藥局   臺北市    中正區   武昌街1段29號1樓   黃盟婷     女    2381-5229         Y
# 2   開業    保德中華藥局   臺北市    中正區    中華路二段159號   蕭宇凱     男  02-23027720         Y
# 3   開業    71恩典藥局   臺北市    中正區     信義路二段71號   洪增陽     男     23223371         Y
# 4   開業      豐仁藥局   臺北市    中正區     寧波西街161號   黃敬堯     男  02-23033908         Y

# %%
pattern = r'[0-9]*?[零一二三四五六七八九十]*?[0-9]*?[零一二三四五六七八九十]{1}[0-9]*?[號]'
df['地址'] = df['地址縣市別'] + df['地址鄉鎮市區'] + df['地址街道巷弄號']

# %%
df.head()
# Out:
#   機構狀態      機構名稱 地址縣市別 地址鄉鎮市區      地址街道巷弄號 負責人姓名 負責人性別           電話 是否為健保特約藥局  \
# 0   開業  活力健康藥妝藥局   臺北市    中正區  中華路二段315巷1號   蕭聖鈞     男     23392625         Y
# 1   開業    建祥武昌藥局   臺北市    中正區   武昌街1段29號1樓   黃盟婷     女    2381-5229         Y
# 2   開業    保德中華藥局   臺北市    中正區    中華路二段159號   蕭宇凱     男  02-23027720         Y
# 3   開業    71恩典藥局   臺北市    中正區     信義路二段71號   洪增陽     男     23223371         Y
# 4   開業      豐仁藥局   臺北市    中正區     寧波西街161號   黃敬堯     男  02-23033908         Y
#
#                   地址
# 0  臺北市中正區中華路二段315巷1號
# 1   臺北市中正區武昌街1段29號1樓
# 2    臺北市中正區中華路二段159號
# 3     臺北市中正區信義路二段71號
# 4     臺北市中正區寧波西街161號

# %%
df['修正地址'] = df['地址'].str.contains(pattern,regex=True)
df.head()
# Out:
#   機構狀態      機構名稱 地址縣市別 地址鄉鎮市區      地址街道巷弄號 負責人姓名 負責人性別           電話 是否為健保特約藥局  \
# 0   開業  活力健康藥妝藥局   臺北市    中正區  中華路二段315巷1號   蕭聖鈞     男     23392625         Y
# 1   開業    建祥武昌藥局   臺北市    中正區   武昌街1段29號1樓   黃盟婷     女    2381-5229         Y
# 2   開業    保德中華藥局   臺北市    中正區    中華路二段159號   蕭宇凱     男  02-23027720         Y
# 3   開業    71恩典藥局   臺北市    中正區     信義路二段71號   洪增陽     男     23223371         Y
# 4   開業      豐仁藥局   臺北市    中正區     寧波西街161號   黃敬堯     男  02-23033908         Y
#
#                   地址   修正地址
# 0  臺北市中正區中華路二段315巷1號  False
# 1   臺北市中正區武昌街1段29號1樓  False
# 2    臺北市中正區中華路二段159號  False
# 3     臺北市中正區信義路二段71號  False
# 4     臺北市中正區寧波西街161號  False

# %%
df['地址'] = htf.h2f(df['地址'])
df.to_csv('../rawdata/medical_facilities/pre_pharmacy.csv')

# %%
wctc.write('../rawdata/medical_facilities/pre_pharmacy.csv', 'pharmacy_WGS84.csv', 10, 11)
# Out:
# progress: 100.0000%:  ▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋▋

# %%
df = pd.read_csv('../rawdata/public_safety/PoliceAddress1_1110715.csv', encoding = 'utf-8')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   中文單位名稱   1692 non-null   object
#  1   英文單位名稱   1692 non-null   object
#  2   郵遞區號     1692 non-null   int64
#  3   地址       1692 non-null   object
#  4   電話       1692 non-null   object
#  5   POINT_X  1692 non-null   float64
#  6   POINT_Y  1692 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 92.7+ KB
#      中文單位名稱                           英文單位名稱  郵遞區號                地址  \
# 0  臺北市政府警察局    Taipei City Police Department   100     臺北市中正區延平南路96號
# 1      中山分局               Zhongshan Precinct   104    臺北市中山區中山北路2段1號
# 2    中山一派出所   Zhongshan First Police Station   104  臺北市中山區中山北路1段110號
# 3    中山二派出所  Zhongshan Second Police Station   104   臺北市中山區中山北路2段90號
# 4     圓山派出所          Yuanshan Police Staticn   104   臺北市中山區中山北路3段62號
#
#             電話      POINT_X      POINT_Y
# 0  02 23313561  301442.6468  2770733.688
# 1  02 25412491  302750.6974  2771704.464
# 2  02 25519321  302613.5457  2771415.780
# 3  02 25517771  302727.2356  2772263.722
# 4  02 25969433  302834.9838  2773933.985

# %%
#df = df.dropna(subset=["lon"])
#df['lon'] = pd.to_numeric(df['lon'],errors='coerce')
#df['lat'] = pd.to_numeric(df['lat'],errors='coerce')
geom = [Point(xy) for xy in zip(df['POINT_X'], df['POINT_Y'])]
#crs = {'init': 'epsg:4326'}
crs = {'init': 'epsg:3826'}
gf = gpd.GeoDataFrame(df, crs=crs, geometry=geom)
#gf = gf.to_crs(epsg=3826)
gf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   中文單位名稱    1692 non-null   object
#  1   英文單位名稱    1692 non-null   object
#  2   郵遞區號      1692 non-null   int64
#  3   地址        1692 non-null   object
#  4   電話        1692 non-null   object
#  5   POINT_X   1692 non-null   float64
#  6   POINT_Y   1692 non-null   float64
#  7   geometry  1692 non-null   geometry
# dtypes: float64(2), geometry(1), int64(1), object(4)
# memory usage: 105.9+ KB
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
#gf = gf[['機構名稱', 'geometry']]
#filt = (gf['型態別'].str.contains('中醫', na=False)) | (gf['型態別'].str.contains('西醫', na=False))
#filt = (gf['型態別'].str.contains('牙醫', na=False))
#gf = gf.loc[filt,['機構名稱', '型態別', 'geometry']]
gf = gf[['中文單位名稱','POINT_X','POINT_Y', 'geometry']]
gf.to_file(f'./public_safety/police' + ".geojson", driver='GeoJSON')
